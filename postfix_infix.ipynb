# %% [markdown]
# ## Part 1: Postfix expression processing

# %%
def is_operator(symbol):
    """ If variable is not  in operator, Checks to see if operator is valid """
    if symbol not in ('+', '-', '*', '/', '%', '//', '**'):
        print("incorrect input passed\n")
        return False
    else:
        return True


class ArrayStack1(list):
    """LIFO Stack implementation using a Python list as underlying storage.
     Extends built-in 'list' class.  """

    def is_empty(self):
        """Return True if the stack is empty."""
        return len(self) == 0

    def push(self, e):
        """Add element e to the top of the stack."""
        super().append(e)  # new item stored at end of list

    def top(self):
        """Return (but do not remove) the element at the top of the stack.
    Raise Empty exception if the stack is empty.
    """
        if self.is_empty():
            print(Exception('Stack is empty'))
        return self[-1]  # the last item in the list

    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).
    Raise Empty exception if the stack is empty.
    """
        if self.is_empty():
            print(Exception('Stack is empty\n'))
        else:
            return super().pop()
        # remove last item from list

    def empty_stack(self):
        while not S == []:
            S.pop()
            
            
PFList = ('7 5 +',
          '7 5 -',
          '7 5 *',
          '7 5 /',
          '8 4 @',
          '8 4 / 2 * 3 +',
          '8 4 / 2 * 3 *',
          '6 8 4 / 2 * 4 + -',
          '100 100 * 20 /',
          '200 w * 10 +',
          '7 6 15 11 2 * + * 20 + -',
          '3 4 5 * + * 6 + ',
          '10 20 30 40 * + * 50 +')

# %%
# code to test that the expressions are correctly separated and can be parsed.
# Do not include in the assignment submission.
S = ArrayStack1()

for ex in PFList:
    x = ex.split(' ')
    print('*' * 80)
    print('Expression: ', ex)
    print('Converted to a list:     \t', x, '\n')
    S.empty_stack()

    for num in x:
        if num.isdigit():
            S.push(num)
            print(num, "has been pushed on to stack :", S)

        elif not num.isdigit():  # if the next expression is not a a number
            op = num  # set it to the operator variable
            operator = is_operator(op)  # send to

            if operator & (len(S) > 1 | S.is_empty()):  # if  operator True pop last to values
                try:
                    val1 = S.pop()
                    print(val1, "has been popped: ", S)
                    val2 = S.pop()
                    print(val2, "has been popped: ", S)
                    # calculate the last 2 values and push into stack and print

                    solved_expression = (str(eval(val2 + num + val1 + '\n')))
                    S.push(solved_expression)
                    print(solved_expression, 'has been pushed: ', S)

                except None:
                    break
                print('result: ', solved_expression)

            else:
                # if value has a incorrect operand push None
                print('Sorry error has occurred')
                break
# Out:
# ********************************************************************************
# Expression:  7 5 +
# Converted to a list:     	 ['7', '5', '+']
#
# 7 has been pushed on to stack : ['7']
# 5 has been pushed on to stack : ['7', '5']
# 5 has been popped:  ['7']
# 7 has been popped:  []
# 12 has been pushed:  ['12']
# result:  12
# ********************************************************************************
# Expression:  7 5 -
# Converted to a list:     	 ['7', '5', '-']
#
# 7 has been pushed on to stack : ['7']
# 5 has been pushed on to stack : ['7', '5']
# 5 has been popped:  ['7']
# 7 has been popped:  []
# 2 has been pushed:  ['2']
# result:  2
# ********************************************************************************
# Expression:  7 5 *
# Converted to a list:     	 ['7', '5', '*']
#
# 7 has been pushed on to stack : ['7']
# 5 has been pushed on to stack : ['7', '5']
# 5 has been popped:  ['7']
# 7 has been popped:  []
# 35 has been pushed:  ['35']
# result:  35
# ...

# %% [markdown]
# ## Part 2 Infix to post fix

# %%
class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self):
        """Create an empty stack."""
        self._data = []  # nonpublic list instance

    def __len__(self):
        """Return the number of elements in the stack."""
        return len(self._data)

    def is_empty(self):
        """Return True if the stack is empty."""
        return len(self._data) == 0

    def push(self, e):
        """Add element e to the top of the stack."""
        self._data.append(e)  # new item stored at end of list

    def top(self):
        """Return (but do not remove) the element at the top of the stack.
        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty('Stack is empty')
        return self._data[-1]  # the last item in the list

    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).
        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty('Stack is empty')
        return self._data.pop()  # remove last item from list

    def showStack(self):  # Added by GRS to display stack contents
        """ Display the contents of the stack top to bottom, without 'pop'. """
        print('\nContents of stack from top to bottom:')
        print('[', end='')
        for s in range(len(self._data) - 1, -1, -1):
            print(self._data[s], '  ', end='')
        print(']')

    def empty_stack(self):
        while not S.data == []:
            S.data.pop()
        else:
            pass

    @property
    def data(self):
        return self._data


class Empty(Exception):
    """Simple 'Empty' exception - used as message pass-through. GRS """
    pass


IFList = ('7 + 5 ',
          '7 - 5 ',
          '7 * 5 ',
          '15 / 5 ',
          '8 $ 4 ',
          '8 / 4 * 2 + 3 ',
          '8 / 4 + 2 * 3 ',
          '16 - 8 / 4 * 2 * 4 ',
          '100 * 100 / 20 + 55 ',
          '200 w * 10 +',
          '( 4 + 5 * 3 ) - 6',
          '( 3 * ( 4 + 5 ) + 6 ',
          '( ( 30 * 40 ) + 20 ) * 10 + 50 ')

# %%
S = ArrayStack()
Priority = {'+': 1, '-': 1, '*': 2, '/': 2, '(': -1}
Operators = set(['+', '-', '*', '/'])
output = ''
for ex in IFList:
    x = ex.split()
    print('*' * 80)
    print('Expression: ', ex)
    print('Expression Converted to a list :', x ,'\n')

    for token in x:
        token.strip('')
        # if token is not in operators list push it to output string
        if token.isdigit():
            output += token + ' '  # token is a digit put into string 
        elif token.isalpha() or token == '$':
            print("ERROR: MOVING ON TO NEXT EXPRESSION ") # just a unsophisticated error catching for our use case 
            break
        elif token == '(':
            S.push(token)
        elif token == ')':
            while S.top() != '(' and (not S.is_empty()):   # if top is not ( and stack is not empty
                output += S.top() + ' '   # write top to strinf 
                S.pop()   # pop item on stack 
            if S.top() == '(':    # if top is ( pop it 
                S.pop()
        elif token in Operators:   # if token is operator just push it to stack if empty
            if S.is_empty():
                S.push(token)
            else:    #  if stack is not empty and there is a opertor check priority 

                if Priority[token] > Priority[S.top()]:   # check priotity and push 
                    S.push(token)

                else: 
                    # while stack is not empty and the priotity of token is less then top write to string pop and then push token 
                    while not S.is_empty() and Priority[token] <= Priority[S.top()]: 
                        output += S.top() + ' '    
                        S.pop()
                    S.push(token)
# while loop for remaining items in stack 
    while not (S.is_empty()):
        output += S.top() + ' '
        S.pop()
        if '(' in output:
            print("ERROR MOVING TO NEXT EXPRESSION")
            break
        else:
            print('Results : ', output)
    # clear output string for next expression         
    output = ''
# Out:
# ********************************************************************************
# Expression:  7 + 5
# Expression Converted to a list : ['7', '+', '5']
#
# Results :  7 5 +
# ********************************************************************************
# Expression:  7 - 5
# Expression Converted to a list : ['7', '-', '5']
#
# Results :  7 5 -
# ********************************************************************************
# Expression:  7 * 5
# Expression Converted to a list : ['7', '*', '5']
#
# Results :  7 5 *
# ********************************************************************************
# Expression:  15 / 5
# Expression Converted to a list : ['15', '/', '5']
#
# Results :  15 5 /
# ********************************************************************************
# Expression:  8 $ 4
# Expression Converted to a list : ['8', '$', '4']
#
# ERROR: MOVING ON TO NEXT EXPRESSION
# ********************************************************************************
# ...
